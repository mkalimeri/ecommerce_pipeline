# %%
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
import seaborn as sns
from datetime import datetime, time
from collections import namedtuple

# %%
def accept_float(value):
    if value is None:
        return np.NaN
    try:
        return float(value)
    except ValueError:
        return np.NaN
    
def is_float(value):
    try:
        float(value)
        return True
    except ValueError:
        return False
    
def reject_float(value):
    if value is None:
        return np.NaN
    if is_float(value):
        return np.NaN
    else:
        return value
    
def get_month_year(timestamp):
    try:
        # 2020-04-24 11:50:39 UTC
        ft = datetime.strptime(timestamp, '%Y-%m-%d %H:%M:%S %Z')
        return datetime.strftime(ft, "%Y-%m")
    except:
        print('error')
        return None

# %%
sales = pd.read_csv('data/electronics_sales.csv')
sales_copy = sales.copy()

display(sales.dtypes)
sales.head()
# Out:
# event_time        object
# order_id           int64
# product_id         int64
# category_id      float64
# category_code     object
# brand             object
# price            float64
# user_id          float64
# dtype: object
#                 event_time             order_id           product_id  \
# 0  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4  2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
#
#     category_id                category_code    brand   price       user_id
# 0  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 1  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 2  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 3  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 4  2.268105e+18                          NaN  karcher  217.57  1.515916e+18

# %%
sales.head()
# Out:
#                 event_time             order_id           product_id  \
# 0  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4  2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
#
#     category_id                category_code    brand   price       user_id
# 0  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 1  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 2  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 3  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 4  2.268105e+18                          NaN  karcher  217.57  1.515916e+18

# %%
sales.describe()
# Out:
#            order_id    product_id   category_id         price       user_id
# count  2.633521e+06  2.633521e+06  2.201567e+06  2.201567e+06  5.641690e+05
# mean   2.361783e+18  1.674080e+18  2.273827e+18  1.540932e+02  1.515916e+18
# std    1.716538e+16  3.102249e+17  2.353247e+16  2.419421e+02  2.379057e+07
# min    2.294360e+18  1.515966e+18  2.268105e+18  0.000000e+00  1.515916e+18
# 25%    2.348807e+18  1.515966e+18  2.268105e+18  1.456000e+01  1.515916e+18
# 50%    2.353254e+18  1.515966e+18  2.268105e+18  5.553000e+01  1.515916e+18
# 75%    2.383131e+18  1.515966e+18  2.268105e+18  1.967400e+02  1.515916e+18
# max    2.388441e+18  2.388434e+18  2.374499e+18  5.092590e+04  1.515916e+18

# %%
display(sales.isna().sum()/sales.shape[0])
# Out:
# event_time       0.000000
# order_id         0.000000
# product_id       0.000000
# category_id      0.164021
# category_code    0.232465
# brand            0.192140
# price            0.164021
# user_id          0.785774
# dtype: float64

# %%
sales.loc[sales.category_id.isna(),:]
# Out:
#                       event_time             order_id           product_id  \
# 1812     2020-05-02 11:12:20 UTC  2300138854784434309  1515966223509353669
# 3633     2020-05-06 07:37:55 UTC  2302930038149874117  1515966223509128764
# 3918     2020-05-06 22:36:13 UTC  2303382163636093788  1515966223510204743
# 6015     2020-05-10 09:41:54 UTC  2305891548316827762  1515966223509353669
# 7802     2020-05-13 03:09:39 UTC  2307868447599493180  1515966223510600539
# ...                          ...                  ...                  ...
# 2632423  2020-11-19 11:34:56 UTC  2388440981134693047  2388434452476082043
# 2632434  2020-11-19 05:38:31 UTC  2388440981134693055  1515966223523303300
# 2632437  2020-11-19 11:21:22 UTC  2388440981134693056  1515966223523303302
# 2632472  2020-11-19 09:54:22 UTC  2388440981134693073  2388434452476685318
# 2632511  2020-11-13 19:46:20 UTC  2388440981134693099  2388434452474499352
#
#          category_id category_code                brand  price  user_id
# 1812             NaN          0.02  1515915625453675584    NaN      NaN
# 3633             NaN         38.17  1515915625455624044    NaN      NaN
# 3918             NaN          0.02  1515915625441101795    NaN      NaN
# 6015             NaN          0.02  1515915625441980762    NaN      NaN
# 7802             NaN          0.02  1515915625441293616    NaN      NaN
# ...              ...           ...                  ...    ...      ...
# 2632423          NaN         16.18  1515915625514803713    NaN      NaN
# 2632434          NaN         13.87  1515915625514803718    NaN      NaN
# 2632437          NaN         57.87  1515915625514803719    NaN      NaN
# 2632472          NaN          5.76  1515915625514155115    NaN      NaN
# 2632511          NaN          0.00  1515915625514803864    NaN      NaN
#
# [431954 rows x 8 columns]

# %%
sales.price.fillna(sales.category_code, inplace=True)
sales.user_id.fillna(sales.brand, inplace=True)

sales.user_id = sales.user_id.apply(accept_float)
# print(sales[sales.user_id=='pastel'])

sales.user_id.fillna(0, inplace=True)
sales.price = sales.price.apply(accept_float)
sales.price.fillna(0, inplace=True)
sales.category_id.fillna(0, inplace=True)

sales.brand = sales.brand.apply(reject_float)
sales.brand.fillna('unknown', inplace=True)
sales.brand.loc[sales.brand=='none'] = 'unknown'
display(sales.brand.unique())
# Out:
# /var/folders/h3/nfz97p4s4nbfn9k6j6f6cknh0000gn/T/ipykernel_22026/2393954873.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales.brand.loc[sales.brand=='none'] = 'unknown'
# array(['samsung', 'huawei', 'karcher', 'maestro', 'apple', 'lg',
#        'polaris', 'intel', 'philips', 'asus', 'unknown', 'epson', 'sbs',
#        'geyzer', 'tefal', 'kingston', 'ava', 'barjher', 'beurer',
#        'schwiizer', 'scarlett', 'caso', 'nokia', 'vivo', 'aoc',
#        'logitech', 'maxwell', 'vitek', 'panasonic', 'moulinex', 'sony',
#        'bork', 'imetec', 'sjcam', 'braun', 'lenovo', 'redmond', 'xiaomi',
#        'globber', 'rondell', 'iqos', 'lavazza', 'razer', 'delux',
#        'prestigio', 'ausini', 'rastar', 'steelseries', 'microlab',
#        'thomas', 'trust', 'ariston', 'fissman', 'ship', 'hyperx', 'neo',
#        'bloody', 'hp', 'tp-link', 'toshiba', 'honor', 'akvafor',
#        'jandeks', 'technodom', 'x-game', 'e.gov', 'perilla', 'xbox',
#        'usams', 'varta', 'beko', 'jbl', 'muljhtidom', 'genius', 'apollo',
#        'kenwood', 'altel', 'thermex', 'gezatone', 'bosch', 'rowenta',
#        'inhouse', 'berghoff', 'svetocopy', 'plantronics', 'birjusa',
#        'peterhof', 'd-link', 'china', 'delonghi', 'canon', 'cremesso',
#        'toro', 'moshi', 'zeppelin', 'gopro', 'deluxe', 'portcase', 'oppo',
#        'hotpoint-ariston', 'pgytech', 'glasslock', 'krups', 'filtero',
#        'jetpik', 'dxracer', 'cougar', 'europrint', 'duracell', 'onanoff',
#        'rapoo', 'indesit', 'deepcool', 'rivacase', 'dji', 'camelion',
#        'jetair', 'ggg', 'aksion', 'hansa', 'zowie', 'midea', 'ipower',
#        'babyliss', 'ritmix', 'kyocera', 'transcend', 'lumax', 'advantek',
#        'lihom', 'ecocool', 'electrolux', 'wacom', 'gorenje', 'borasco',
#        'sumdex', 'atlant', 'jaguar', 'powerplant', 'gtec', 'hoco',
#        'gigabyte', 'yoobao', 'sencor', 'a-case', 'remington', 'tvs',
#        'oral-b', 'lego', 'mercusys', 'nika', 'provence', 'elari',
#        'fujifilm', 'aquapick', 'microsoft', 'awei', 'singer', 'amazon',
#        'astonish', 'continent', 'victoria', 'organ', 'msi', 'goodyear',
#        'joby', 'huion', 'zhiyun', 'satechi', 'timson', 'wintek',
#        'spiegelau', 'e-blue', 'ergolux', 'tcl', 'xp-pen', 'king',
#        'colorful', 'dyson', 'motorola', 'global', 'nikon', 'nintendo',
#        'omron', 'barkan', 'mujjo', 'screentec', 'gutrend', 'ninebot',
#        'spigen', 'svc', 'simax', 'bradex', 'wilmax', 'aoki', 'patriot',
#        'pyrex', 'huter', 'aqua', 'grans', 'pasabahce', 'google',
#        'polimerbiht', 'celebrat', 'id-cooling', 'wonlex', 'emsa',
#        'thermaltake', 'huntkey', 'nv-print', 'flama', 'gamemax', 'paclan',
#        'jabra', 'cullmann', 'edifier', 'mlife', 'irbis', 'arnica',
#        'tenda', 'pastel', 'kaabo', 'activision', 'dr.beckmann', 'bona',
#        'ehlektrostandart', 'aquadent', 'haushalt', 'garmin', 'gefest',
#        'borner', 'ruggear', 'atmor', 'moizen', 'ozone', 'komax',
#        'greenway', 'tucano', 'anymode', 'tailg', 'trio', 'galaxy', 'cdc',
#        'simfer', 'marcato', 'coolinar', 'laurastar', 'att', 'janome',
#        'luminarc', 'osz', 'tayfun', 'almatv', 'caspio', 'temdan', 'orico',
#        'different', 'bellissima', 'cort', 'wmf', 'topperr', 'aimoto',
#        'asrock', 'neoline', 'hyundai', 'bestway', 'insight', 'designskin',
#        'compliment', 'micro', 'fly', 'plextor', 'xgimi', 'jura', 'amd',
#        'hoya', 'aerocool', 'weber', 'thule', 'bose', 'mattel', 'marshall',
#        'pozis', 'ubisoft', 'altex', 'navitel', 'moxom', 'dogland',
#        'dewalt', 'gembird', 'belcando', 'daewoo', 'kitchenaid', 'airline',
#        'resanta', 'select', 'metsui', 'kenko', 'parachute', 'samsonite',
#        'bioderma', 'smart', 'wethepeople', 'olympus', 'yamaguchi', 'dell',
#        'zwilling', 'ehra', 'dam', 'sanc', 'kicx', 'gerat', 'intex',
#        'smeg', 'nordland', 'pocketbook', 'covim', 'inkax', 'rockstar',
#        'matador', 'continental', 'alis', 'fitokosmetik', 'feja', 'wurth',
#        'chicco', 'akpo', 'xigmatek', 'wilson', 'sonnet', 'lowepro',
#        'zlatek', 'bykski', 'eyfel', 'zeta', 'aquael', 'art.fit', 'tramp',
#        'blehk', 'sibel', 'caramelia', 'mitasu', 'buebchen', 'kivi',
#        'kink', 'farmtek', 'nuk', 'manfrotto', 'wxd', 'eglo', 'alex',
#        'medela', 'ivolia', 'baboo', 'vitehks', 'nivea', 'taoran',
#        'kramet', 'uteki', 'fila', 'blw', 'acana', 'puff', 'dahon',
#        'jockey', 'giant', 'esthederm', 'lukoyl', 'misty', 'rosneftjh',
#        'accesstyle', 'subini', 'titania', 'owner', 'okuma', 'kosadaka',
#        'habilead', 'marley', 'kitekat', 'lactacyd', 'mobil', 'centara',
#        'zala', 'casio', 'powertrac', 'akom', 'bardahl', 'inspector',
#        'franke', 'rubineta', 'pedigree', 'polini', 'technomax', 'aeg',
#        'savic', 'phantom', 'starline', 'casada', 'status', 'wirek',
#        'mepps', 'myrans', 'turbo', 'arktika', 'nvidia', 'kama', 'jonsbo',
#        'erlit', 'alfa', 'lavr', 'trw', 'kumano', 'reno', 'iiyama',
#        'nutralash', 'shelkovica', 'mueller', 'avermedia', 'dabur',
#        'essence', 'catrice', 'crucial', 'garanterm', 'grohe', 'hintek',
#        'lion', 'canyon', 'kiepe', 'ogx', 'samura', 'sakura', 'aura',
#        'seagate', 'lemark', 'ezviz', 'vikhrjh', 'domini', 'brother',
#        'sibrtekh', 'neptun', 'belita', 'curver', 'regnum', 'stanley',
#        'biostar', 'artberry', 'luch', 'staedtler', 'stabilo', 'swager',
#        'kerasys', 'farmona', 'akku', 'pccooler', 'president', 'whirlpool',
#        'yokohama', 'x-cooler', 'kona', 'hiwatch', 'palit', 'skullcandy',
#        'riva', 'optoma', 'gamdias', 'technogym', 'prana', 'nascita',
#        'palisad', 'olimpik', 'saramonic', 'navien', 'author', 'babolat',
#        'jvc', 'millet', 'cralusso', 'fenix', 'staub', 'domani-spa',
#        'promtorgservis', 'urbanears', 'viatti', 'higashi', 'delmax',
#        'ecologystone', 'eurolux', 'fender', 'swat', 'incase', 'loewe',
#        'skingard', 'tsg', 'venta', 'belitam', 'rossija', 'alinco',
#        'ezetil', 'novatrack', 'daikin', 'roevuta', 'leefitness',
#        'pioneer', 'biol', 'saeco', 'fiio', 'demidovskiy', 'pandora',
#        'kmk', 'superlux', 'melitta', 'alienware', 'sigma', 'brateck',
#        'milight', 'nzxt', 'arena', 'beats', 'corsair', 'matrix',
#        'legrand', 'tamron', 'henkel', 'htc', 'boyscout', 'cilek',
#        'megogo', 'awax', 'thefaceshop', 'eset', 'goodride', 'zugo',
#        'okko', 'finish', 'dermoviva', 'amigami', 'fossil', 'lol',
#        'sparta', 'procab', 'medisana', 'glassware', 'mart', 'parkcity',
#        'fjallraven', 'kovea', 'monge', 'navitagi', 'pemco', 'steba',
#        'cablexpert', 'nitto', 'areca', 'pi-pi-bent', 'stikbot',
#        'everlast', 'unitabs', 'art.home', 'lamart', 'cannondale',
#        'avrora', 'polaroid', 'speedo', 'bethesda', 'joonies', 'zemex',
#        'apc', 'alpengaudi', 'decoroom', 'today', 'uriage', 'iwalk',
#        'dc-girls', 'solite', 'ideal', 'bisfree', 'opadiris', 'forward',
#        'collecta', 'atom', 'delsey', 'ikins', 'virtuix', 'ivi', 'bruder',
#        'jimu', 'gemon', 'simba', 'rombica', 'playme', 'montblanc',
#        'monkart', 'rioba', 'fieldmann', 'vinzer', 'proscreen', 'jb',
#        'golf', 'zalman', 'whiskas', 'energea', 'egoiste', 'adidas',
#        'bushido', 'calgon', 'audac', 'xerox', 'makita', 'teorema',
#        'herschel', 'giottos', 'byintek', 'timberk', 'luxell', 'wikium',
#        'meizu', 'sennheiser', 'jimi', 'lotte', 'metalions', 'granchio',
#        'roeyuta', 'etalon', 'd-color', 'altair', 'kixx', 'bauer', 'hurom',
#        'blackstar', 'kodak', 'sportop', 'uniq', 'prism', 'symphony',
#        'barbie', 'raduga', 'pirelli', 'bissell', 'dougez', 'beaphar',
#        'bsf', 'tyr', 'liebherr', 'makeblock', 'geil', 'maybelline',
#        'silverlit', 'ramili', 'bjurokrat', 'promount', 'crane', 'hitachi',
#        'skyworth', 'versace', 'cars', 'unicharm', 'michelin', 'allvega',
#        'sports', 'lenspen', 'phanteks', 'biomio', 'elica', 'terminus',
#        'baltextile', 'biolane', 'roca', 'akvaton', 'smile', 'paulig',
#        'rocketbook', 'miele', 'bourjois', 'pixel', 'colorfix', 'texet',
#        'blackvue', 'cayin', 'jack', 'noctua', 'qnap', 'lanvin', 'fixsen',
#        'leonardo', 'qmax', 'fibaro', 'momentum', 'seasonic', 'gogarden',
#        'g.skill', 'zenit', 'cinemood', 'luremax', 'tion', 'synology',
#        'unicum', 'tetchair', 'moov', 'hasbro', 'kristall-auto',
#        'paperline', 'ubiquiti', 'filtrete', 'msep', 'aehrolayf', 'vaude',
#        'tribe', 'stels', 'suunto', 'asics', 'batihrihch', 'gewa',
#        'mikasa', 'marcel', 'cubicfun', 'kurzweil', 'joerex', 'dk',
#        'daiwa', 'stiga', 'balsax', 'help', 'vortex', 'cybex', 'durobor',
#        'beeline', 'parrot', 'kaspersky', 'artel', 'shenzhen', 'rinnai',
#        'kartal', 'samovar', 'povarjonok', 'cube', 'bridgestone',
#        'vitabiotics', 'denzel', 'mirage', 'mtx', 'bbag', 'arlan', 'yukon',
#        'burton', 'gillette', 'dermal', 'isolon', 'ectaco', 'er',
#        'netatmo', 'chistotel', 'segotep', 'depileve', 'mannol',
#        'crewelter', 'nommi', 'axper', 'zhorka', 'fsp', 'yiling', 'squier',
#        'eurostil', 'petzl', 'brelil', 'tornado', 'botas', 'chameleon',
#        'linglong', 'stinger', 'toyo', 'kumho', 'highwaybaby', 'footwork',
#        'prologic', 'voin', 'silverex', 'joma', 'estia', 'mcdavid',
#        'cersanit', 'berkley', 'farcar', 'osprey', 'cow', 'char-broil',
#        'tece', 'zanussi', 'mio', 'jose', 'milan', 'eastcoast', 'grillver',
#        'venum', 'kose', 'imbema', 'nixx', 'berry', 'sibirjh', 'evere',
#        'mazzini', 'ecopro', 'kiturami', 'metabo', 'dittmann', 'action',
#        'goliath', 'harper', 'avel', 'citoderm', 'bequiet', 'deerma',
#        'defender', 'cliny', 'generis', 'imou', 'swag', 'salomon',
#        'moldabela', 'ionkini', 'tacx', 'rdx', 'teksdizayn', 'outwell',
#        'clinch', 'nomi', 'buff', 'sandisk', 'korg', 'darina', 'disney',
#        'santek', 'lefard', 'roadx', 'totalbox', 'topeak', 'waterrower',
#        'elfe', 'nokian', 'marvel', 'mantra', 'runwin', 'bfgoodrich',
#        'limpopo', 'feather', 'tigar', 'gislaved', 'akitio', 'finis',
#        'sunwide', 'genau', 'romana', 'smallrig', 'billna', 'meridian',
#        'agu', 'lori', 'stihl', 'go-sport', 'orion', 'yonker', 'ockel',
#        'titan', 'teploljuks', 'resto', 'nepia', 'hms', 'aist',
#        'realflame', 'hukuba', 'ta-sport', 'vipe', 'frosch', 'ride',
#        'anon', 'lange', 'gross', 'tigernu', 'cyberpower', 'megabass',
#        'premierfit', 'masterica', 'aiko', 'fizan', 'adguard', 'alpina',
#        'inoi', 'hygge', 'treaclemoon', 'index', 'merries', 'nissan',
#        'molnija', 'dauscher', 'scierra', 'apacer', 'pigeon', 'nakamichi',
#        'konami', 'dynastar', 'boneco', 'neonode', 'chayka', 'grundfos',
#        'oma', 'ugreen', 'fischer', 'benq', 'zevs'], dtype=object)

# %%
display(sum(sales.category_code.unique()=='none'))
# Out:
# 0

# %%
sales.category_code = sales.category_code.apply(reject_float)

sales.category_code.fillna('unknown', inplace=True)

display(sales.isna().sum()/sales.shape[0])
# Out:
# event_time       0.0
# order_id         0.0
# product_id       0.0
# category_id      0.0
# category_code    0.0
# brand            0.0
# price            0.0
# user_id          0.0
# dtype: float64

# %%
sales.category_code.unique()
# Out:
# array(['electronics.tablet', 'electronics.audio.headphone', 'unknown',
#        'furniture.kitchen.table', 'electronics.smartphone',
#        'appliances.kitchen.refrigerators', 'appliances.personal.scales',
#        'electronics.video.tv', 'computers.components.cpu',
#        'computers.notebook', 'computers.peripherals.monitor',
#        'computers.peripherals.printer', 'appliances.kitchen.kettle',
#        'computers.components.memory', 'electronics.clocks',
#        'country_yard.weather_station', 'appliances.kitchen.blender',
#        'accessories.bag', 'computers.peripherals.keyboard',
#        'computers.peripherals.mouse', 'appliances.iron',
#        'appliances.kitchen.mixer', 'electronics.telephone',
#        'appliances.kitchen.meat_grinder',
#        'appliances.personal.hair_cutter',
#        'appliances.environment.air_heater', 'kids.skates',
#        'appliances.kitchen.washer', 'appliances.kitchen.microwave',
#        'furniture.bedroom.pillow', 'appliances.environment.vacuum',
#        'appliances.environment.water_heater',
#        'furniture.living_room.shelving', 'computers.components.cooler',
#        'computers.peripherals.joystick', 'computers.network.router',
#        'computers.components.hdd', 'appliances.kitchen.hood',
#        'appliances.ironing_board', 'apparel.glove', 'stationery.battery',
#        'construction.tools.screw', 'furniture.bedroom.bed',
#        'stationery.cartrige', 'appliances.environment.air_conditioner',
#        'appliances.kitchen.grill', 'appliances.personal.massager',
#        'appliances.kitchen.toster', 'appliances.environment.fan',
#        'stationery.paper', 'computers.gaming',
#        'appliances.kitchen.coffee_machine',
#        'computers.peripherals.camera', 'computers.peripherals.scanner',
#        'furniture.living_room.chair', 'computers.components.power_supply',
#        'electronics.audio.microphone', 'apparel.trousers',
#        'medicine.tools.tonometer', 'appliances.kitchen.juicer',
#        'appliances.kitchen.oven', 'appliances.kitchen.dishwasher',
#        'apparel.shirt', 'furniture.kitchen.chair',
#        'appliances.sewing_machine', 'computers.desktop',
#        'furniture.living_room.cabinet', 'computers.components.videocards',
#        'appliances.kitchen.coffee_grinder', 'computers.ebooks',
#        'apparel.tshirt', 'electronics.audio.acoustic',
#        'auto.accessories.compressor', 'stationery.stapler',
#        'computers.components.cdrw', 'appliances.kitchen.fryer',
#        'appliances.kitchen.steam_cooker', 'kids.toys',
#        'appliances.environment.climate',
#        'computers.components.motherboard', 'country_yard.lawn_mower',
#        'furniture.living_room.sofa', 'sport.bicycle', 'apparel.sock',
#        'auto.accessories.videoregister', 'electronics.video.projector',
#        'electronics.camera.photo', 'sport.tennis',
#        'furniture.bathroom.bath', 'appliances.steam_cleaner',
#        'construction.tools.heater', 'electronics.camera.video',
#        'kids.carriage', 'sport.trainer', 'apparel.costume',
#        'construction.tools.drill', 'kids.bottles',
#        'furniture.universal.light', 'construction.components.faucet',
#        'country_yard.cultivator', 'electronics.calculator',
#        'electronics.audio.subwoofer', 'auto.accessories.alarm',
#        'auto.accessories.anti_freeze', 'furniture.bedroom.blanket',
#        'sport.diving', 'computers.components.sound_card', 'kids.dolls',
#        'auto.accessories.player', 'accessories.umbrella',
#        'construction.tools.saw', 'construction.tools.welding',
#        'construction.tools.generator', 'sport.ski', 'kids.swing',
#        'construction.tools.pump', 'construction.tools.light',
#        'electronics.audio.dictaphone', 'auto.accessories.radar',
#        'kids.fmcg.diapers', 'furniture.bathroom.toilet',
#        'sport.snowboard', 'country_yard.watering', 'apparel.shoes'],
#       dtype=object)

# %%
sum(sales.brand.unique() == 'other')
# Out:
# 0

# %%
sales = sales.astype({
    'event_time':'string',
    'category_id':'int64', 
    'category_code':'string',
    'brand':'string', 
    'user_id':'int64'
})

# %%
sales['year_month'] = sales['event_time'].apply(get_month_year)
# sales.to_parquet('total_sales.parquet')
# sales.head()

# %%
months = sales.year_month.unique()
for m in months:
    sales_m = sales[sales.year_month == m]
    sales_m.to_parquet(f'sales_{m}.parquet')

# %%
sales.year_month.unique()
# Out:
# array(['2020-04', '2020-05', '2020-06', '1970-01', '2020-07', '2020-01',
#        '2020-02', '2020-03', '2020-08', '2020-09', '2020-10', '2020-11'],
#       dtype=object)
